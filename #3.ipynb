# %% [markdown]
# ## #3 [Medium]
#
# This problem was asked by Google.
#
# Given the root to a binary tree, implement `serialize(root)`, which serializes the tree into a string, and `deserialize(s)`, which deserializes the string back into the tree.
#
# For example, given the following `Node` class
#
# ```
# class Node:
#     def __init__(self, val, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
# ```
#
# The following test should pass:
#
# ```
# node = Node('root', Node('left', Node('left.left')), Node('right'))
# assert deserialize(serialize(node)).left.left.val == 'left.left'
# ```

# %%
class Node:
    def __init__(self, val, left = None, right = None):
        self.val = val
        self.left = left
        self.right = right
        
def serialize(node):
    if not node:
        return "[]"
    
    return "[{} {} {}]".format(node.val, serialize(node.left), serialize(node.right))

def deserialize_recursive(str):
    n = Node('')
    got_left = False
    i = 0
    
    def idx(i):
        return i - 1
    
    while i < len(str):
        i += 1
        
        if idx(i) == 0 or str[idx(i)] == " ":
            continue
            
        if str[idx(i)] == '[':
            child, index = deserialize_recursive(str[idx(i):])
            
            if not got_left:
                n.left = child
                got_left = True
                i = i + index
                continue
            
            n.right = child
            i = i + index
            continue
        
        if str[idx(i)] == ']':
            if not n.val:
                return None, idx(i)
            
            return n, idx(i)
            
        n.val += str[idx(i)]
            
    return n, 0
            
def deserialize(str):
    return deserialize_recursive(str)[0]
        
root = Node('root', Node('left', Node('left.left')), Node('right'))

assert deserialize(serialize(root)).left.left.val == 'left.left'
